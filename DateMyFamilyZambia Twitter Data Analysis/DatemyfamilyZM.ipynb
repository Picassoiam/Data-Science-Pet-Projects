# %%
# !pip install twitterscraper
# !pip install wordcloud
# Out:
# Requirement already satisfied: twitterscraper in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (0.9.3)
# Requirement already satisfied: lxml in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from twitterscraper) (4.2.5)
# Requirement already satisfied: bs4 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from twitterscraper) (0.0.1)
# Requirement already satisfied: requests in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from twitterscraper) (2.21.0)
# Requirement already satisfied: coala-utils~=0.5.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from twitterscraper) (0.5.1)
# Requirement already satisfied: beautifulsoup4 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from bs4->twitterscraper) (4.6.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests->twitterscraper) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests->twitterscraper) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests->twitterscraper) (2018.10.15)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests->twitterscraper) (1.23)
# Requirement already satisfied: wordcloud in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from wordcloud) (1.14.6)
# Requirement already satisfied: pillow in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from wordcloud) (5.3.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import datetime as dt
import nltk
from nltk import bigrams 
import  datetime as dt
from collections import Counter 
# %matplotlib inline
from twitterscraper import query_tweets
from wordcloud import WordCloud, STOPWORDS
from textblob import TextBlob
from textblob import Word
from textblob.sentiments import NaiveBayesAnalyzer

# %%
#fetching tweet data using twitterscraper
def fetch_tweets():
    list_of_tweets = query_tweets("#DateMyFamilyZambia", 1000, begindate=dt.date(2019, 1, 1), enddate=dt.date(2019,4,10))
    tweets_dicts=[]
    for tweet in list_of_tweets:
        tweetObj={'likes':tweet.likes,'replies':tweet.replies,'text':tweet.text,'user':tweet.user,'timestamp':tweet.timestamp,'retweets':tweet.retweets}
        tweets_dicts.append(tweetObj)
    df = pd.DataFrame(tweets_dicts)
    return df


df=fetch_tweets()
writer = pd.ExcelWriter('DateMyFamilyZambia.xlsx')
df.to_excel(writer,'Sheet1')
writer.save()
# Out:
# INFO: queries: ['#DateMyFamilyZambia since:2019-01-01 until:2019-01-05', '#DateMyFamilyZambia since:2019-01-05 until:2019-01-10', '#DateMyFamilyZambia since:2019-01-10 until:2019-01-15', '#DateMyFamilyZambia since:2019-01-15 until:2019-01-20', '#DateMyFamilyZambia since:2019-01-20 until:2019-01-25', '#DateMyFamilyZambia since:2019-01-25 until:2019-01-30', '#DateMyFamilyZambia since:2019-01-30 until:2019-02-04', '#DateMyFamilyZambia since:2019-02-04 until:2019-02-09', '#DateMyFamilyZambia since:2019-02-09 until:2019-02-14', '#DateMyFamilyZambia since:2019-02-14 until:2019-02-19', '#DateMyFamilyZambia since:2019-02-19 until:2019-02-24', '#DateMyFamilyZambia since:2019-02-24 until:2019-03-01', '#DateMyFamilyZambia since:2019-03-01 until:2019-03-06', '#DateMyFamilyZambia since:2019-03-06 until:2019-03-11', '#DateMyFamilyZambia since:2019-03-11 until:2019-03-16', '#DateMyFamilyZambia since:2019-03-16 until:2019-03-21', '#DateMyFamilyZambia since:2019-03-21 until:2019-03-26', '#DateMyFamilyZambia since:2019-03-26 until:2019-03-31', '#DateMyFamilyZambia since:2019-03-31 until:2019-04-05', '#DateMyFamilyZambia since:2019-04-05 until:2019-04-10']
# INFO: Querying #DateMyFamilyZambia since:2019-01-05 until:2019-01-10
# INFO: Querying #DateMyFamilyZambia since:2019-01-01 until:2019-01-05
# INFO: Querying #DateMyFamilyZambia since:2019-01-10 until:2019-01-15
# INFO: Querying #DateMyFamilyZambia since:2019-01-20 until:2019-01-25
# INFO: Querying #DateMyFamilyZambia since:2019-02-24 until:2019-03-01
# INFO: Querying #DateMyFamilyZambia since:2019-03-06 until:2019-03-11
# INFO: Querying #DateMyFamilyZambia since:2019-01-30 until:2019-02-04
# INFO: Querying #DateMyFamilyZambia since:2019-02-04 until:2019-02-09
# INFO: Querying #DateMyFamilyZambia since:2019-02-09 until:2019-02-14
# INFO: Querying #DateMyFamilyZambia since:2019-02-14 until:2019-02-19
# INFO: Querying #DateMyFamilyZambia since:2019-03-31 until:2019-04-05
# INFO: Querying #DateMyFamilyZambia since:2019-01-25 until:2019-01-30
# INFO: Querying #DateMyFamilyZambia since:2019-03-21 until:2019-03-26
# INFO: Querying #DateMyFamilyZambia since:2019-03-16 until:2019-03-21
# INFO: Querying #DateMyFamilyZambia since:2019-04-05 until:2019-04-10
# INFO: Querying #DateMyFamilyZambia since:2019-03-26 until:2019-03-31
# INFO: Querying #DateMyFamilyZambia since:2019-03-01 until:2019-03-06
# INFO: Querying #DateMyFamilyZambia since:2019-02-19 until:2019-02-24
# INFO: Querying #DateMyFamilyZambia since:2019-03-11 until:2019-03-16
# INFO: Querying #DateMyFamilyZambia since:2019-01-15 until:2019-01-20
# INFO: Got 7 tweets for %23DateMyFamilyZambia%20since%3A2019-01-05%20until%3A2019-01-10.
# INFO: Got 7 tweets (7 new).
# INFO: Got 14 tweets for %23DateMyFamilyZambia%20since%3A2019-02-09%20until%3A2019-02-14.
# INFO: Got 21 tweets (14 new).
# INFO: Got 60 tweets for %23DateMyFamilyZambia%20since%3A2019-01-20%20until%3A2019-01-25.
# INFO: Got 47 tweets for %23DateMyFamilyZambia%20since%3A2019-01-25%20until%3A2019-01-30.
# INFO: Got 20 tweets for %23DateMyFamilyZambia%20since%3A2019-03-01%20until%3A2019-03-06.
# INFO: Got 81 tweets (60 new).
# INFO: Got 60 tweets for %23DateMyFamilyZambia%20since%3A2019-01-10%20until%3A2019-01-15.
# INFO: Got 128 tweets (47 new).
# INFO: Got 148 tweets (20 new).
# INFO: Got 208 tweets (60 new).
# INFO: Got 18 tweets for %23DateMyFamilyZambia%20since%3A2019-03-16%20until%3A2019-03-21.
# INFO: Got 226 tweets (18 new).
# INFO: Got 58 tweets for %23DateMyFamilyZambia%20since%3A2019-01-01%20until%3A2019-01-05.
# INFO: Got 284 tweets (58 new).
# INFO: Got 60 tweets for %23DateMyFamilyZambia%20since%3A2019-02-24%20until%3A2019-03-01.
# INFO: Got 60 tweets for %23DateMyFamilyZambia%20since%3A2019-02-19%20until%3A2019-02-24.
# INFO: Got 344 tweets (60 new).
# INFO: Got 404 tweets (60 new).
# INFO: Got 60 tweets for %23DateMyFamilyZambia%20since%3A2019-03-06%20until%3A2019-03-11.
# INFO: Got 464 tweets (60 new).
# INFO: Got 60 tweets for %23DateMyFamilyZambia%20since%3A2019-02-14%20until%3A2019-02-19.
# INFO: Got 524 tweets (60 new).
# INFO: Got 60 tweets for %23DateMyFamilyZambia%20since%3A2019-03-11%20until%3A2019-03-16.
# INFO: Got 584 tweets (60 new).
# INFO: Got 60 tweets for %23DateMyFamilyZambia%20since%3A2019-03-26%20until%3A2019-03-31.
# INFO: Got 60 tweets for %23DateMyFamilyZambia%20since%3A2019-03-21%20until%3A2019-03-26.
# INFO: Got 644 tweets (60 new).
# INFO: Got 704 tweets (60 new).
# INFO: Got 15 tweets for %23DateMyFamilyZambia%20since%3A2019-04-05%20until%3A2019-04-10.
# INFO: Got 719 tweets (15 new).
# INFO: Got 60 tweets for %23DateMyFamilyZambia%20since%3A2019-03-31%20until%3A2019-04-05.
# INFO: Got 779 tweets (60 new).
# INFO: Got 60 tweets for %23DateMyFamilyZambia%20since%3A2019-02-04%20until%3A2019-02-09.
# INFO: Got 839 tweets (60 new).
# INFO: Got 60 tweets for %23DateMyFamilyZambia%20since%3A2019-01-30%20until%3A2019-02-04.
# INFO: Got 899 tweets (60 new).
# INFO: Got 60 tweets for %23DateMyFamilyZambia%20since%3A2019-01-15%20until%3A2019-01-20.
# INFO: Got 959 tweets (60 new).

# %%
#Lets rename our data frame to twdata
df
# Out:
#      likes  replies  retweets  \
# 0        0        0         0
# 1        2        1         0
# 2        0        0         0
# 3        0        0         0
# 4        0        0         0
# 5        0        0         0
# 6        0        0         0
# 7        8        1         0
# 8        5        1         1
# 9        0        0         0
# 10      31        6         1
# 11       1        1         0
# 12       4        1         2
# 13       2        1         2
# 14       0        0         0
# 15       1        0         0
# 16       0        0         0
# 17       1        0         0
# 18       1        2         0
# 19       1        0         0
# 20       0        0         0
# 21       0        0         0
# 22      10        0         1
# 23       1        0         0
# 24       1        1         0
# 25       1        1         0
# 26       2        0         0
# 27       0        0         0
# 28       5        0         0
# 29       1        0         0
# ..     ...      ...       ...
# 929      0        0         0
# 930      0        0         0
# 931      2        1         0
# 932      0        1         0
# 933      1        0         0
# 934      0        0         0
# 935      5        1         1
# 936     11        1         2
# 937      3        0         1
# 938      3        0         0
# 939      1        0         1
# 940      0        0         0
# 941      1        0         0
# 942      0        0         0
# 943      0        0         0
# 944      2        0         0
# 945      5        0         0
# 946      2        0         0
# 947      5        1         0
# 948      2        0         0
# 949     15        3         2
# 950      1        0         0
# 951      0        0         0
# 952      0        0         0
# 953      5        2         0
# 954      1        0         0
# 955      1        0         0
# 956      3        0         0
# 957      1        0         0
# 958      1        0         0
#
#                                                   text           timestamp  \
# 0    the differences between #datemyfamilyzambia an... 2019-01-09 17:27:47
# 1    She didn’t pick Mwayi?? Whaaaat?!!!! #DateMyFa... 2019-01-06 17:51:08
# 2    I still can't get over wow wow wow wow ...cute... 2019-01-06 17:13:10
# 3           Catching the repeat of #datemyfamilyZambia 2019-01-05 13:10:44
# 4    I am so over #DatemyFamilyZambia.The whole thi... 2019-01-05 11:37:38
# 5    So I'm a Mum and I am basically lame and total... 2019-01-05 06:37:56
# 6    Ba Nathan ati "you have missed out on a chance... 2019-01-05 06:37:56
# 7    I'm sorry this when I'm finally getting the ch... 2019-02-13 17:21:53
# 8    In this economy the best you can do is stay ho... 2019-02-13 11:27:32
# 9    Shout out to Joe's honesty over his very own b... 2019-02-12 16:40:22
# 10   It's disconcerting how the suitors on #datemyf... 2019-02-11 20:23:13
# 11   Some Lusaka social scene faces in this Thursda... 2019-02-11 17:36:58
# 12   @chucky_Beau ninshi #datemyfamilyZambia is you... 2019-02-11 16:05:26
# 13   @chucky_Beau I've seen your ass on the next ep... 2019-02-11 15:30:07
# 14   Martha the reason they didn't pick you is beca... 2019-02-11 09:43:13
# 15   Date my family Zambia presenter be like Tina i... 2019-02-11 09:40:48
# 16       Hmmm ,  .  Those eyebrows #datemyfamilyZambia 2019-02-10 17:11:00
# 17   #datemyfamilyZambia is brilliant. The most aut... 2019-02-10 15:46:34
# 18   @chabs_cc I found you! I have so many question... 2019-02-09 15:30:05
# 19   We said grace before we cooked  #datemyfamilyZ... 2019-02-09 12:53:05
# 20   Am i the only one who didn't tweet about  #dat... 2019-02-09 06:18:09
# 21   Imwe Mary's family sure  ati na menshi ayakaba... 2019-01-24 23:58:20
# 949  -1.000000       Negative
# 950   0.200000       Positive
# 951   0.000000        Neutral
# 952   0.300000       Positive
# 953   0.000000        Neutral
# 954   0.000000        Neutral
# 955   0.000000        Neutral
# 956   0.000000        Neutral
# 957   0.250000       Positive
# 958   0.300000       Positive
#
# [959 rows x 12 columns]

# %%
#Cleaning data
twdata['time_date']=pd.to_datetime(twdata['timestamp'])
twdata['date'] = [d.date() for d in twdata['time_date']]
twdata['time'] = [d.time() for d in twdata['time_date']]
twdata['hour']= twdata.time_date.dt.hour

# %%
#Finding the most influencial Tweeter
def convert_index_most_liked(tweep_most_likes_df):
    index_list=np.array(tweep_most_likes_df.index)
    tweeps=[]
    for index,user_from_index  in enumerate (index_list):
        total_likes=tweep_most_likes_df['likes'][index]
        likes_per_user={'user':user_from_index,'number_of_likes':total_likes}
        tweeps.append(likes_per_user)
    return tweeps

tweep_group=twdata.groupby('user')
tweep_most_likes=tweep_group['likes'].sum()
tweep_most_likes_df_temp=pd.DataFrame(tweep_most_likes)
tweep_most_likes_df=pd.DataFrame(tweep_most_likes_df_temp['likes'])
   
temp=convert_index_most_liked(tweep_most_likes_df)
most_likes_df=pd.DataFrame(temp)
most_liked_tweets=most_likes_df.sort_values(by='number_of_likes')

g = sns.barplot(x='user',y='number_of_likes',data=most_liked_tweets.tail(15))
for item in g.get_xticklabels():
    item.set_rotation(90)

# %%
#finding the tweep with the most retweets
most_retweeted_tweeps_sum=twdata.groupby('user')['retweets'].sum()
temp=pd.DataFrame(most_retweeted_tweeps_sum)
                  
def convert_index_most_retweeted(tweep_most_retweeted_df):
    index_list=np.array(tweep_most_likes_df.index)
    tweeps=[]
    for index,user_from_index  in enumerate (index_list):
        total_retweets=tweep_most_retweeted_df['retweets'][index]
        retweets_per_user={'user':user_from_index,'number_of_retweets':total_retweets}
        tweeps.append(retweets_per_user)
    return pd.DataFrame(tweeps)
most_retweeted_tweeps_df=convert_index_most_retweeted(temp)
most_retweeted_tweeps_sorted=most_retweeted_tweeps_df.sort_values(by='number_of_retweets')

#render the bar graph
g=sns.barplot(x='user',y='number_of_retweets',data=most_retweeted_tweeps_sorted.tail(15))
for item in g.get_xticklabels():
    item.set_rotation(90)

# %%
#Who tweeted the Most about the Show?
g=sns.countplot(x='user',data=data, order=pd.value_counts(data['user']).iloc[:20].index)
for item in g.get_xticklabels():
    item.set_rotation(90)

# %%
#We will be appending the words to this var
comment_words = ' ' 

#Finds all stop words in the set of tweets.
stopwords = set(STOPWORDS) 

 #convert all tweet content into strings
for val in df.text:
   val = str(val)
#Split all strings into individual components
   tokens = val.split() 
   for i in range(len(tokens)):
#Converts all the individual strings to lower case.
      tokens[i] = tokens[i].lower() 
for words in tokens:
   comment_words = comment_words + words + ' '
wordcloud=WordCloud(width=1000,height=1000, background_color='white', stopwords=stopwords,min_font_size=10).generate(comment_words)

#All of this is a single line
plt.figure(figsize=(5,10),facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
data_set=twdata

# %%
text = data_set["text"]

for i in range(0,len(text)):
    textB = TextBlob(text[i])
    sentiment = textB.sentiment.polarity
    data_set.set_value(i, 'Sentiment',sentiment)
    if sentiment <0.00:
        SentimentClass = 'Negative'
        data_set.set_value(i, 'SentimentClass', SentimentClass )
    elif sentiment >0.00:
        SentimentClass = 'Positive'
        data_set.set_value(i, 'SentimentClass', SentimentClass )
    else:
        SentimentClass = 'Neutral'
        data_set.set_value(i, 'SentimentClass', SentimentClass )
        
feels = data_set.to_csv('sentiment4dmfz.csv')
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
data = pd.read_csv('sentiment4dmfz.csv')
data
# Out:
#      Unnamed: 0  likes  replies  retweets  \
# 0             0      0        0         0
# 1             1      2        1         0
# 2             2      0        0         0
# 3             3      0        0         0
# 4             4      0        0         0
# 5             5      0        0         0
# 6             6      0        0         0
# 7             7      8        1         0
# 8             8      5        1         1
# 9             9      0        0         0
# 10           10     31        6         1
# 11           11      1        1         0
# 12           12      4        1         2
# 13           13      2        1         2
# 14           14      0        0         0
# 15           15      1        0         0
# 16           16      0        0         0
# 17           17      1        0         0
# 18           18      1        2         0
# 19           19      1        0         0
# 20           20      0        0         0
# 21           21      0        0         0
# 22           22     10        0         1
# 23           23      1        0         0
# 24           24      1        1         0
# 25           25      1        1         0
# 26           26      2        0         0
# 27           27      0        0         0
# 28           28      5        0         0
# 29           29      1        0         0
# ..          ...    ...      ...       ...
# 929         929      0        0         0
# 930         930      0        0         0
# 931         931      2        1         0
# 932         932      0        1         0
# 933         933      1        0         0
# 934         934      0        0         0
# 935         935      5        1         1
# 936         936     11        1         2
# 937         937      3        0         1
# 938         938      3        0         0
# 939         939      1        0         1
# 940         940      0        0         0
# 941         941      1        0         0
# 942         942      0        0         0
# 943         943      0        0         0
# 944         944      2        0         0
# 945         945      5        0         0
# 946         946      2        0         0
# 947         947      5        1         0
# 948         948      2        0         0
# 949         949     15        3         2
# 950         950      1        0         0
# 951         951      0        0         0
# 952         952      0        0         0
# 953         953      5        2         0
# 954         954      1        0         0
# 955         955      1        0         0
# 956         956      3        0         0
# 957         957      1        0         0
# 958         958      1        0         0
#
#                                                   text            timestamp  \
# 0    the differences between #datemyfamilyzambia an...  2019-01-09 17:27:47
# 1    She didn’t pick Mwayi?? Whaaaat?!!!! #DateMyFa...  2019-01-06 17:51:08
# 2    I still can't get over wow wow wow wow ...cute...  2019-01-06 17:13:10
# 3           Catching the repeat of #datemyfamilyZambia  2019-01-05 13:10:44
# 4    I am so over #DatemyFamilyZambia.The whole thi...  2019-01-05 11:37:38
# 5    So I'm a Mum and I am basically lame and total...  2019-01-05 06:37:56
# 6    Ba Nathan ati "you have missed out on a chance...  2019-01-05 06:37:56
# 7    I'm sorry this when I'm finally getting the ch...  2019-02-13 17:21:53
# 8    In this economy the best you can do is stay ho...  2019-02-13 11:27:32
# 9    Shout out to Joe's honesty over his very own b...  2019-02-12 16:40:22
# 10   It's disconcerting how the suitors on #datemyf...  2019-02-11 20:23:13
# 11   Some Lusaka social scene faces in this Thursda...  2019-02-11 17:36:58
# 12   @chucky_Beau ninshi #datemyfamilyZambia is you...  2019-02-11 16:05:26
# 26    0.100000       Positive
# 27   -0.025000       Negative
# 28    0.000000        Neutral
# 29    0.000000        Neutral
# ..         ...            ...
# 929   0.000000        Neutral
# 930  -0.500000       Negative
# 931   0.000000        Neutral
# 932   0.000000        Neutral
# 933   0.600000       Positive
# 934   0.400000       Positive
# 935   0.000000        Neutral
# 936  -0.050000       Negative
# 937   0.000000        Neutral
# 938  -0.071429       Negative
# 939   0.400000       Positive
# 940   0.000000        Neutral
# 941   0.000000        Neutral
# 942  -0.625000       Negative
# 943   0.000000        Neutral
# 944   0.000000        Neutral
# 945  -0.600000       Negative
# 946   0.900000       Positive
# 947  -0.500000       Negative
# 948   0.381746       Positive
# 949  -1.000000       Negative
# 950   0.200000       Positive
# 951   0.000000        Neutral
# 952   0.300000       Positive
# 953   0.000000        Neutral
# 954   0.000000        Neutral
# 955   0.000000        Neutral
# 956   0.000000        Neutral
# 957   0.250000       Positive
# 958   0.300000       Positive
#
# [959 rows x 13 columns]

# %%
#What were the sentiments aroud the show?
sns.countplot(x='SentimentClass',data=data)

# %%
date_tweet_count=twdata['date'].value_counts()

# %%
def convert_index_column(df_tweet_count):
    index_list=np.array(df_tweet_count.index)
    tweets_list=[]
    for index,date_from_index  in enumerate (index_list):
        tweets_counts=df_tweet_count['date'][index]
        tweets_per_day={'date':date_from_index,'number_of_tweets':tweets_counts}
        tweets_list.append(tweets_per_day)
    return tweets_list

# %%
df_tweet_date_count=pd.DataFrame(data=date_tweet_count)
tweets_per_day=convert_index_column(df_tweet_date_count)
tweets_per_day_df=pd.DataFrame(tweets_per_day)

# %%
tweets_per_day_df.plot.line(x=tweets_per_day_df['date'],y='number_of_tweets',figsize=(25,8),lw=1)

# %%
hour_tweet_count=twdata['hour'].value_counts()
df_tweet_hour_count=pd.DataFrame(data=hour_tweet_count)

# %%
def convert_index_hour(df_tweet_count):
    index_list=np.array(df_tweet_count.index)
    tweets_list=[]
    for index,hour_from_index  in enumerate (index_list):
        tweets_counts=df_tweet_count['hour'][hour_from_index]
        hour=str(hour_from_index)+"hrs"
        tweets_per_hour={'hour':hour,'number_of_tweets':tweets_counts}
        tweets_list.append(tweets_per_hour)
    return tweets_list

# %%
tweets_per_hour=convert_index_hour(df_tweet_hour_count)
tweets_per_hour_df=pd.DataFrame(tweets_per_hour)
tweets_per_hour_df
# Out:
#      hour  number_of_tweets
# 0   20hrs               471
# 1   21hrs                88
# 2   16hrs                47
# 3    6hrs                42
# 4    5hrs                41
# 5   17hrs                31
# 6   15hrs                29
# 7    9hrs                25
# 8    7hrs                24
# 9    8hrs                20
# 10  18hrs                19
# 11  22hrs                19
# 12  11hrs                16
# 13  10hrs                16
# 14  12hrs                13
# 15  13hrs                12
# 16  19hrs                10
# 17   4hrs                10
# 18  23hrs                 9
# 19   0hrs                 6
# 20  14hrs                 4
# 21   3hrs                 4
# 22   1hrs                 3

# %%
#Hour with the most tweets?
g=sns.barplot(x='hour',y='number_of_tweets',data=tweets_per_hour_df)
for item in g.get_xticklabels():
    item.set_rotation(90)
